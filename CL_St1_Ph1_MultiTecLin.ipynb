# %% [markdown]
# <center>
# <img src="https://laelgelcpublic.s3.sa-east-1.amazonaws.com/lael_50_years_narrow_white.png.no_years.400px_96dpi.png" width="300" alt="LAEL 50 years logo">
# <h3>APPLIED LINGUISTICS GRADUATE PROGRAMME (LAEL)</h3>
# </center>
# <hr>

# %% [markdown]
# # Revising Academic Writing with ChatGPT

# %% [markdown]
# ## What is `python-docx`?

# %% [markdown]
# `python-docx` is a Python library for reading, creating, and updating Microsoft Word 2007+ (.docx) files.
#
# Please refer to:
# - [5 Best Ways to Read Microsoft Word Documents with Python](https://blog.finxter.com/5-best-ways-to-read-microsoft-word-documents-with-python/)

# %% [markdown]
# ## Required Python packages

# %% [markdown]
# - openai
# - pandas
# - python-dotenv
# - tqdm
# - python-docx

# %% [markdown]
# ## Importing the required libraries

# %%
from docx import Document
from dotenv import load_dotenv
import openai
import pandas as pd
import os
import sys
import logging
from tqdm import tqdm
import time

# %% [markdown]
# ## Defining input variables

# %%
input_directory = 'cl_st1_ph1_multiteclin_input'
output_directory = 'cl_st1_ph1_multiteclin_output'
log_filename = 'cl_st1_ph1_multiteclin.log'
docx_filename = 'Ensaio Alexandre Rodrigues Nunes inglês.docx'
txt_filename = 'Ensaio Alexandre Rodrigues Nunes inglês python-docx.txt'
df_filename1 = 'cl_st1_ph1_multiteclin_df1'
df_filename2 = 'cl_st1_ph1_multiteclin_df2'

# %% [markdown]
# ## Creating output directory

# %%
# Check if the output directory already exists. If it does, do nothing. If it doesn't exist, create it.
if os.path.exists(output_directory):
    print('Output directory already exists.')
else:
    try:
        os.makedirs(output_directory)
        print('Output directory successfully created.')
    except OSError as e:
        print('Failed to create the directory:', e)
        sys.exit(1)
# Out:
# Output directory successfully created.

# %% [markdown]
# ## Setting up logging

# %%
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(levelname)s - %(message)s',
    filename = f"{output_directory}/{log_filename}"
)

# %% [markdown]
# ## `python-docx` DOCX scraping

# %% [markdown]
# ### Setting required variables

# %%
docx_path = f"{input_directory}/{docx_filename}"
output_txt = f"{output_directory}/{txt_filename}"
paragraph_num = 0

# %% [markdown]
# ### Sampling paragraphs

# %%
doc = Document(docx_path)
paragraph = doc.paragraphs[paragraph_num]
text = paragraph.text
text
# Out:
# 'Academic Essay: The Pedagogy of Multiliteracies Applied to English Teaching'

# %% [markdown]
# ### Scraping the entire document

# %%
def scrape_docx(docx_path, output_txt):
    # Opening the DOCX file
    doc = Document(docx_path)

    # Initialising an empty string to store the text
    text_list = []

    # Iterating through all the paragraphs and extract text
    for paragraph in doc.paragraphs:
        text_list.append(paragraph.text)

    text = '\n'.join(text_list)
    
    # Writing the extracted text to a text file in UTF-8 encoding
    with open(output_txt, 'w', encoding='utf-8') as txt_file:
        txt_file.write(text)

scrape_docx(docx_path, output_txt)
print('DOCX scraped successfully!')
# Out:
# DOCX scraped successfully!

# %% [markdown]
# ## Manually editing the text file according to the following format

# %% [markdown]
# ```
# Text ID: t000000
#
# Title: The Pedagogy of Multiliteracies Applied to English Teaching
#
# Section: Introduction
# The teaching of foreign languages ...
# The concept of multiliteracies, ...
# <other paragraphs>
#
# Section: Body
# The Pedagogy of Multiliteracies is ...
# The Pedagogy of Multiliteracies ...
# <other paragraphs>
#
# Section: Conclusion
# The Pedagogy of Multiliteracies emerges ...
# The creation of fanfictions within ...
# <other paragraphs>
# ```

# %% [markdown]
# ## Importing the text into a DataFrame

# %%
# Initialising variables
text_id = None
title = None
section = None
paragraph_count = 0
data = []

# Reading the file
logging.info('Starting to read the file')
with open(output_txt, 'r', encoding='utf-8') as file:
    for line in file:
        line = ' '.join(line.split())  # Removing duplicated spaces
        line = line.strip()
        
        # Capturing 'Text ID'
        if line.startswith('Text ID:'):
            text_id = line.split(': ')[1]
            logging.info(f"Captured Text ID: {text_id}")
        
        # Capturing 'Title'
        elif line.startswith('Title:'):
            title = line.split(': ')[1]
            logging.info(f"Captured Title: {title}")
        
        # Capturing 'Section'
        elif line.startswith('Section:'):
            section = line.split(': ')[1]
            paragraph_count = 0  # Resetting paragraph count for new section
            logging.info(f"Starting new section: {section}")
        
        # Capturing 'Paragraph Text'
        elif line:
            paragraph_count += 1
            data.append({
                'Text ID': text_id,
                'Title': title,
                'Section': section,
                'Paragraph': f"Paragraph {paragraph_count}",
                'Text Paragraph': line
            })
            logging.info(f"Captured Paragraph {paragraph_count} in Section: {section}")

# Creating DataFrame
df_text = pd.DataFrame(data)
logging.info('DataFrame created successfully')

# %%
df_text
# Out:
#     Text ID                                              Title  \
# 0   t000000  The Pedagogy of Multiliteracies Applied to Eng...
# 1   t000000  The Pedagogy of Multiliteracies Applied to Eng...
# 2   t000000  The Pedagogy of Multiliteracies Applied to Eng...
# 3   t000000  The Pedagogy of Multiliteracies Applied to Eng...
# 4   t000000  The Pedagogy of Multiliteracies Applied to Eng...
# 5   t000000  The Pedagogy of Multiliteracies Applied to Eng...
# 6   t000000  The Pedagogy of Multiliteracies Applied to Eng...
# 7   t000000  The Pedagogy of Multiliteracies Applied to Eng...
# 8   t000000  The Pedagogy of Multiliteracies Applied to Eng...
# 9   t000000  The Pedagogy of Multiliteracies Applied to Eng...
# 10  t000000  The Pedagogy of Multiliteracies Applied to Eng...
# 11  t000000  The Pedagogy of Multiliteracies Applied to Eng...
# 12  t000000  The Pedagogy of Multiliteracies Applied to Eng...
# 13  t000000  The Pedagogy of Multiliteracies Applied to Eng...
# 14  t000000  The Pedagogy of Multiliteracies Applied to Eng...
# 15  t000000  The Pedagogy of Multiliteracies Applied to Eng...
# 16  t000000  The Pedagogy of Multiliteracies Applied to Eng...
# 17  t000000  The Pedagogy of Multiliteracies Applied to Eng...
# 18  t000000  The Pedagogy of Multiliteracies Applied to Eng...
# 19  t000000  The Pedagogy of Multiliteracies Applied to Eng...
# 20  t000000  The Pedagogy of Multiliteracies Applied to Eng...
# 21  t000000  The Pedagogy of Multiliteracies Applied to Eng...
# 22  t000000  The Pedagogy of Multiliteracies Applied to Eng...
# 23  t000000  The Pedagogy of Multiliteracies Applied to Eng...
# 24  t000000  The Pedagogy of Multiliteracies Applied to Eng...
# 25  t000000  The Pedagogy of Multiliteracies Applied to Eng...
# 26  t000000  The Pedagogy of Multiliteracies Applied to Eng...
# 27  t000000  The Pedagogy of Multiliteracies Applied to Eng...
# 28  t000000  The Pedagogy of Multiliteracies Applied to Eng...
# 29  t000000  The Pedagogy of Multiliteracies Applied to Eng...
#
#                  Section     Paragraph  \
# 0           Introduction   Paragraph 1
# 1           Introduction   Paragraph 2
# 2           Introduction   Paragraph 3
# 3            Development   Paragraph 1
# 4            Development   Paragraph 2
# 5            Development   Paragraph 3
# 6            Development   Paragraph 4
# 7            Development   Paragraph 5
# 8            Development   Paragraph 6
# 9            Development   Paragraph 7
# 10           Development   Paragraph 8
# 11           Development   Paragraph 9
# 12           Development  Paragraph 10
# 13           Development  Paragraph 11
# 14           Development  Paragraph 12
# 15           Development  Paragraph 13
# 16           Development  Paragraph 14
# 17           Development  Paragraph 15
# 18           Development  Paragraph 16
# 19           Development  Paragraph 17
# 20           Development  Paragraph 18
# 21           Development  Paragraph 19
# 22           Development  Paragraph 20
# 23  Final Considerations   Paragraph 1
# 24  Final Considerations   Paragraph 2
# 25  Final Considerations   Paragraph 3
# 26  Final Considerations   Paragraph 4
# 27  Final Considerations   Paragraph 5
# 28  Final Considerations   Paragraph 6
# 29  Final Considerations   Paragraph 7
#
#                                        Text Paragraph
# 0   The teaching of foreign languages has evolved ...
# 1   The concept of multiliteracies, introduced by ...
# 2   This essay will first explore the theoretical ...
# 3   The Pedagogy of Multiliteracies is based on th...
# 4   The Pedagogy of Multiliteracies emerges as a c...
# 5   The New London Group's (NLG) manifesto, drafte...
# 6   Another crucial point in this discussion is th...
# 7   In this context, the Pedagogy of Multiliteraci...
# 8   In the English language classroom, the applica...
# 9   The fanfiction genre has become an important p...
# 10  Fanfiction production exemplifies strategies o...
# 11  Furthermore, fanfiction production is intrinsi...
# 12  Finally, analyzing fanfiction production with ...
# 13  The creation of fanfiction in English class, w...
# 14  The analysis of fanfiction in the research was...
# 15  Additionally, we aligned our analysis with the...
# 16  In summary, the analysis procedures adopted in...
# 17  Regarding fanfiction production, beyond lingui...
# 18  The research conducted in this master’s study,...
# 19  It is worth emphasizing the concept of afforda...
# 20  The relationship between the learner and their...
# 21  Beyond environmental affordances, Silva (2015)...
# 22  Finally, the research by Aronin and Singleton ...
# 23  The Pedagogy of Multiliteracies emerges as an ...
# 24  The creation of fanfictions within the school ...
# 25  In addition to linguistic benefits, fanfiction...
# 26  Another relevant aspect is the role of informa...
# 27  Linguistic affordances, in turn, are evidenced...
# 28  The analysis of students' fanfictions also rev...
# 29  In light of the discussion, the Pedagogy of Mu...

# %% [markdown]
# ### Exporting to a file

# %%
df_text.to_json(f"{output_directory}/{df_filename1}.jsonl", orient='records', lines=True)

# %% [markdown]
# ## Revising the paragraphs with ChatGPT

# %% [markdown]
# ### Importing the data into a DataFrame

# %%
df_text = pd.read_json(f"{output_directory}/{df_filename1}.jsonl", lines=True)

# %% [markdown]
# ### Defining input variables

# %%
#chatgpt_prompt = 'Dear ChatGPT, would it be possible for you to improve the writing of the following passage of a research article considering the generally accepted standards of English for Academic Purposes? Please keep each improved passage within a single paragraph - do not split it into multiple paragraphs. OK?'

# %%
chatgpt_prompt = 'Dear ChatGPT, please improve the writing of the following passage of a research article considering the generally accepted standards of English for Academic Purposes. It is very important that you are as objective, scientific and non-metaphorical as you can be. Please keep each improved passage within a single paragraph - do not split it into multiple paragraphs. Also, do not acknowledge this prompt - just provide the revised passage straightaway.'

# %% [markdown]
# ### Revising the paragraphs

# %%
# Loading all environment variables from '.env' into 'os.environ'
load_dotenv()

# Importing the required programme variables from the environment
openai.api_key = os.environ.get('OPENAI_API_KEY', '')
assert openai.api_key

# Defining a function to query ChatGPT with exponential backoff
def get_completion(prompt, model='gpt-4o', max_retries=5):
    client = openai.OpenAI()
    messages = [{'role': 'user', 'content': prompt}]
    for attempt in range(max_retries):
        try:
            response = client.chat.completions.create(
                model=model,
                messages=messages,
                temperature=0
            )
            return response.choices[0].message.content
        except openai.error.RateLimitError as e:
            wait_time = 2 ** attempt  # Exponential backoff
            logging.warning(f"Rate limit exceeded. Retrying in {wait_time} seconds...")
            time.sleep(wait_time)
        except Exception as e:
            logging.error(f"Error querying ChatGPT: {e}")
            return None
    logging.error("Max retries exceeded.")
    return None

# Defining a function to process text using ChatGPT
def process_text(text, prompt_template):
    paragraphs = text.split('\n')  # Splitting text into paragraphs
    processed_paragraphs = []
    for paragraph in paragraphs:
        prompt = prompt_template + paragraph
        try:
            processed_paragraph = get_completion(prompt)
            if processed_paragraph:
                processed_paragraphs.append(processed_paragraph)
            else:
                processed_paragraphs.append(paragraph)  # Keeping original if there's an error
        except Exception as e:
            print(f"Error processing paragraph: {e}")
            processed_paragraphs.append(paragraph)  # Keeping original if there's an error
    return '\n'.join(processed_paragraphs)

# Applying the function to the 'Host Question' column with progress indication
processed_texts = []
for index, row in tqdm(df_text.iterrows(), total=len(df_text), desc='Processing texts'):
    # Defining the ChatGPT prompt template
    prompt_template = chatgpt_prompt + '\n'
    
    # Processing text
    processed_texts.append(process_text(row['Text Paragraph'], prompt_template))

df_text['Text Paragraph ChatGPT'] = processed_texts
# Out:
# Processing texts: 100%|██████████| 30/30 [02:08<00:00,  4.28s/it]

# %%
df_text
# Out:
#     Text ID                                              Title  \
# 0   t000000  The Pedagogy of Multiliteracies Applied to Eng...
# 1   t000000  The Pedagogy of Multiliteracies Applied to Eng...
# 2   t000000  The Pedagogy of Multiliteracies Applied to Eng...
# 3   t000000  The Pedagogy of Multiliteracies Applied to Eng...
# 4   t000000  The Pedagogy of Multiliteracies Applied to Eng...
# 5   t000000  The Pedagogy of Multiliteracies Applied to Eng...
# 6   t000000  The Pedagogy of Multiliteracies Applied to Eng...
# 7   t000000  The Pedagogy of Multiliteracies Applied to Eng...
# 8   t000000  The Pedagogy of Multiliteracies Applied to Eng...
# 9   t000000  The Pedagogy of Multiliteracies Applied to Eng...
# 10  t000000  The Pedagogy of Multiliteracies Applied to Eng...
# 11  t000000  The Pedagogy of Multiliteracies Applied to Eng...
# 12  t000000  The Pedagogy of Multiliteracies Applied to Eng...
# 13  t000000  The Pedagogy of Multiliteracies Applied to Eng...
# 14  t000000  The Pedagogy of Multiliteracies Applied to Eng...
# 15  t000000  The Pedagogy of Multiliteracies Applied to Eng...
# 16  t000000  The Pedagogy of Multiliteracies Applied to Eng...
# 17  t000000  The Pedagogy of Multiliteracies Applied to Eng...
# 18  t000000  The Pedagogy of Multiliteracies Applied to Eng...
# 19  t000000  The Pedagogy of Multiliteracies Applied to Eng...
# 20  t000000  The Pedagogy of Multiliteracies Applied to Eng...
# 21  t000000  The Pedagogy of Multiliteracies Applied to Eng...
# 22  t000000  The Pedagogy of Multiliteracies Applied to Eng...
# 23  t000000  The Pedagogy of Multiliteracies Applied to Eng...
# 24  t000000  The Pedagogy of Multiliteracies Applied to Eng...
# 25  t000000  The Pedagogy of Multiliteracies Applied to Eng...
# 26  t000000  The Pedagogy of Multiliteracies Applied to Eng...
# 27  t000000  The Pedagogy of Multiliteracies Applied to Eng...
# 28  t000000  The Pedagogy of Multiliteracies Applied to Eng...
# 29  t000000  The Pedagogy of Multiliteracies Applied to Eng...
#
#                  Section     Paragraph  \
# 0           Introduction   Paragraph 1
# 1           Introduction   Paragraph 2
# 2           Introduction   Paragraph 3
# 3            Development   Paragraph 1
# 4            Development   Paragraph 2
# 5            Development   Paragraph 3
# 6            Development   Paragraph 4
# 7            Development   Paragraph 5
# 8            Development   Paragraph 6
# 9            Development   Paragraph 7
# 10           Development   Paragraph 8
# 11           Development   Paragraph 9
# 12           Development  Paragraph 10
# 13           Development  Paragraph 11
# 14           Development  Paragraph 12
# 15           Development  Paragraph 13
# 16           Development  Paragraph 14
# 17           Development  Paragraph 15
# 18           Development  Paragraph 16
# 19           Development  Paragraph 17
# 20           Development  Paragraph 18
# 21           Development  Paragraph 19
# 22           Development  Paragraph 20
# 23  Final Considerations   Paragraph 1
# 24  Final Considerations   Paragraph 2
# 25  Final Considerations   Paragraph 3
# 26  Final Considerations   Paragraph 4
# 27  Final Considerations   Paragraph 5
# 28  Final Considerations   Paragraph 6
# 29  Final Considerations   Paragraph 7
#
#                                        Text Paragraph  \
# 0   The teaching of foreign languages has evolved ...
# 1   The concept of multiliteracies, introduced by ...
# 2   This essay will first explore the theoretical ...
# 3   The Pedagogy of Multiliteracies is based on th...
# 4   The Pedagogy of Multiliteracies emerges as a c...
# 5   The New London Group's (NLG) manifesto, drafte...
# 6   Another crucial point in this discussion is th...
# 7   In this context, the Pedagogy of Multiliteraci...
# 8   In the English language classroom, the applica...
# 9   The fanfiction genre has become an important p...
# 10  Fanfiction production exemplifies strategies o...
# 11  Furthermore, fanfiction production is intrinsi...
# 12  Finally, analyzing fanfiction production with ...
# 13  The creation of fanfiction in English class, w...
# 14  The analysis of fanfiction in the research was...
# 15  Additionally, we aligned our analysis with the...
# 16  In summary, the analysis procedures adopted in...
# 17  Regarding fanfiction production, beyond lingui...
# 18  The research conducted in this master’s study,...
# 19  It is worth emphasizing the concept of afforda...
# 20  The relationship between the learner and their...
# 21  Beyond environmental affordances, Silva (2015)...
# 22  Finally, the research by Aronin and Singleton ...
# 23  The Pedagogy of Multiliteracies emerges as an ...
# 24  The creation of fanfictions within the school ...
# 25  In addition to linguistic benefits, fanfiction...
# 26  Another relevant aspect is the role of informa...
# 27  Linguistic affordances, in turn, are evidenced...
# 28  The analysis of students' fanfictions also rev...
# 29  In light of the discussion, the Pedagogy of Mu...
#
#                                Text Paragraph ChatGPT
# 0   The teaching of foreign languages has undergon...
# 1   The concept of multiliteracies, introduced by ...
# 2   This essay initially examines the theoretical ...
# 3   The Pedagogy of Multiliteracies is founded on ...
# 4   The Pedagogy of Multiliteracies represents a c...
# 5   The New London Group's (NLG) manifesto, origin...
# 6   Another important aspect of this discussion is...
# 7   In this context, the Pedagogy of Multiliteraci...
# 8   In the English language classroom, this pedago...
# 9   The fanfiction genre has emerged as a signific...
# 10  Fanfiction production exemplifies strategies s...
# 11  Fanfiction production is closely associated wi...
# 12  Analyzing fanfiction production with intertext...
# 13  The incorporation of fanfiction writing in Eng...
# 14  The analysis of fanfiction in this research wa...
# 15  We aligned our analysis with the principles of...
# 16  In summary, the analytical methods employed in...
# 17  In the context of fanfiction production, beyon...
# 18  This master's study investigated the impact of...
# 19  The concept of affordance, introduced by Gibso...
# 20  The interaction between learners and their env...
# 21  In addition to environmental affordances, Silv...
# 22  Aronin and Singleton (2012) extend the discuss...
# 23  The Pedagogy of Multiliteracies is a crucial a...
# 24  This master's research examines the creation o...
# 25  In addition to linguistic benefits, the produc...
# 26  An important aspect to consider is the role of...
# 27  Linguistic affordances are demonstrated by the...
# 28  The analysis of students' fanfictions highligh...
# 29  The Pedagogy of Multiliteracies, when applied ...

# %% [markdown]
# ### Exporting to a file

# %%
df_text.to_json(f"{output_directory}/{df_filename2}.jsonl", orient='records', lines=True)

# %%
df_text.to_excel(f"{output_directory}/{df_filename2}.xlsx", index=False)
